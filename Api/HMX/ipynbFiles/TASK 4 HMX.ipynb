# %% [markdown]
# # ACTIVE MARKETS

# %%
from web3 import Web3
import time
import os
#import dotenv
from datetime import datetime
from abis import STORAGE_CONFIG_ABI

#dotenv.load_dotenv()
#################### HTTP ALCHEMY URL ARBITRUM ####
ALCHEMY_URL = 'https://arb-mainnet.g.alchemy.com/v2/BR5NFYsO9xS7QvUNw853TPbS19MvqXs-'
w3 = Web3(Web3.HTTPProvider(ALCHEMY_URL))
STORAGE_CONFIG_ADDRESS = "0xF4F7123fFe42c4C90A4bCDD2317D397E0B7d7cc0"


price_monitor_contract = w3.eth.contract(address=STORAGE_CONFIG_ADDRESS, abi=STORAGE_CONFIG_ABI)

# %%
response = price_monitor_contract.functions.getMarketConfigs().call()

# %%
for item in response:
  print("Asset ID:", item[0].decode('utf-8'))
  print("Max Long Position Size:", item[1])
  print("Max Short Position Size:", item[2])
  print("Increase Position Fee Rate BPS:", item[3])
  print("Decrease Position Fee Rate BPS:", item[4])
  print("Initial Margin Fraction BPS:", item[5])
  print("Maintenance Margin Fraction BPS:", item[6]) 
  print("Max Profit Rate BPS:", item[7])
  print("Asset Class:", item[8])
  print("Allow Increase Position:", item[9])
  print("Active:", item[10])
  print("Max Skew Scale USD:", item[11][0])
  print("Max Funding Rate:", item[11][1])
  print("--------------------")
# Out:
# Asset ID: ETH
# Max Long Position Size: 5500000000000000000000000000000000000
# Max Short Position Size: 5500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 4
# Decrease Position Fee Rate BPS: 4
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 350000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 2000000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: BTC
# Max Long Position Size: 6000000000000000000000000000000000000
# Max Short Position Size: 6000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 4
# Decrease Position Fee Rate BPS: 4
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 350000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 3000000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: AAPL
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 200
# Maintenance Margin Fraction BPS: 100
# Max Profit Rate BPS: 100000
# Asset Class: 1
# Allow Increase Position: False
# Active: False
# Max Skew Scale USD: 1000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: JPY
# Max Long Position Size: 3000000000000000000000000000000000000
# Max Short Position Size: 3000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 1
# Decrease Position Fee Rate BPS: 1
# Initial Margin Fraction BPS: 10
# Maintenance Margin Fraction BPS: 5
# Max Profit Rate BPS: 500000
# Asset Class: 2
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: XAU
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 200
# Maintenance Margin Fraction BPS: 100
# Max Profit Rate BPS: 75000
# Asset Class: 3
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: AMZN
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 200
# Maintenance Margin Fraction BPS: 100
# Max Profit Rate BPS: 100000
# Asset Class: 1
# Allow Increase Position: False
# Active: False
# Max Skew Scale USD: 1000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: MSFT
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 200
# Maintenance Margin Fraction BPS: 100
# Max Profit Rate BPS: 100000
# Asset Class: 1
# Allow Increase Position: False
# Active: False
# Max Skew Scale USD: 1000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: TSLA
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 200
# Maintenance Margin Fraction BPS: 100
# Max Profit Rate BPS: 100000
# Asset Class: 1
# Allow Increase Position: False
# Active: False
# Max Skew Scale USD: 1000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: EUR
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 1
# Decrease Position Fee Rate BPS: 1
# Initial Margin Fraction BPS: 10
# Maintenance Margin Fraction BPS: 5
# Max Profit Rate BPS: 500000
# Asset Class: 2
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: XAG
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 200
# Maintenance Margin Fraction BPS: 100
# Max Profit Rate BPS: 75000
# Asset Class: 3
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: AUD
# Max Long Position Size: 3000000000000000000000000000000000000
# Max Short Position Size: 3000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 1
# Decrease Position Fee Rate BPS: 1
# Initial Margin Fraction BPS: 10
# Maintenance Margin Fraction BPS: 5
# Max Profit Rate BPS: 500000
# Asset Class: 2
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: GBP
# Max Long Position Size: 3000000000000000000000000000000000000
# Max Short Position Size: 3000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 1
# Decrease Position Fee Rate BPS: 1
# Initial Margin Fraction BPS: 10
# Maintenance Margin Fraction BPS: 5
# Max Profit Rate BPS: 500000
# Asset Class: 2
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: ADA
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 300000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: MATIC
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 300000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: SUI
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: ARB
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: OP
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: LTC
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: COIN
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 200
# Maintenance Margin Fraction BPS: 100
# Max Profit Rate BPS: 100000
# Asset Class: 1
# Allow Increase Position: False
# Active: False
# Max Skew Scale USD: 500000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: GOOG
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 200
# Maintenance Margin Fraction BPS: 100
# Max Profit Rate BPS: 100000
# Asset Class: 1
# Allow Increase Position: False
# Active: False
# Max Skew Scale USD: 1000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: BNB
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: SOL
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: QQQ
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 200
# Maintenance Margin Fraction BPS: 100
# Max Profit Rate BPS: 100000
# Asset Class: 1
# Allow Increase Position: False
# Active: False
# Max Skew Scale USD: 1000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: XRP
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 500000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: NVDA
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 200
# Maintenance Margin Fraction BPS: 100
# Max Profit Rate BPS: 100000
# Asset Class: 1
# Allow Increase Position: False
# Active: False
# Max Skew Scale USD: 1000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: LINK
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: CHF
# Max Long Position Size: 3000000000000000000000000000000000000
# Max Short Position Size: 3000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 1
# Decrease Position Fee Rate BPS: 1
# Initial Margin Fraction BPS: 10
# Maintenance Margin Fraction BPS: 5
# Max Profit Rate BPS: 500000
# Asset Class: 2
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: DOGE
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 300000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: CAD
# Max Long Position Size: 3000000000000000000000000000000000000
# Max Short Position Size: 3000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 1
# Decrease Position Fee Rate BPS: 1
# Initial Margin Fraction BPS: 10
# Maintenance Margin Fraction BPS: 5
# Max Profit Rate BPS: 500000
# Asset Class: 2
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: SGD
# Max Long Position Size: 3000000000000000000000000000000000000
# Max Short Position Size: 3000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 1
# Decrease Position Fee Rate BPS: 1
# Initial Margin Fraction BPS: 10
# Maintenance Margin Fraction BPS: 5
# Max Profit Rate BPS: 500000
# Asset Class: 2
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: CNH
# Max Long Position Size: 3000000000000000000000000000000000000
# Max Short Position Size: 3000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 1
# Decrease Position Fee Rate BPS: 1
# Initial Margin Fraction BPS: 10
# Maintenance Margin Fraction BPS: 5
# Max Profit Rate BPS: 500000
# Asset Class: 2
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: HKD
# Max Long Position Size: 3000000000000000000000000000000000000
# Max Short Position Size: 3000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 1
# Decrease Position Fee Rate BPS: 1
# Initial Margin Fraction BPS: 10
# Maintenance Margin Fraction BPS: 5
# Max Profit Rate BPS: 500000
# Asset Class: 2
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: BCH
# Max Long Position Size: 2500000000000000000000000000000000000
# Max Short Position Size: 2500000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 300000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: MEME
# Max Long Position Size: 2000000000000000000000000000000000000
# Max Short Position Size: 2000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 300000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: DIX
# Max Long Position Size: 3000000000000000000000000000000000000
# Max Short Position Size: 3000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 1
# Decrease Position Fee Rate BPS: 1
# Initial Margin Fraction BPS: 10
# Maintenance Margin Fraction BPS: 5
# Max Profit Rate BPS: 250000
# Asset Class: 2
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: JTO
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: STX
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: ORDI
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: TIA
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: AVAX
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: INJ
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: DOT
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: SEI
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: ATOM
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: 1000PEPE
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: 1000SHIB
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: SEK
# Max Long Position Size: 3000000000000000000000000000000000000
# Max Short Position Size: 3000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 1
# Decrease Position Fee Rate BPS: 1
# Initial Margin Fraction BPS: 10
# Maintenance Margin Fraction BPS: 5
# Max Profit Rate BPS: 500000
# Asset Class: 2
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 10000000000000000000000000000000000000000
# Max Funding Rate: 1000000000000000000
# --------------------
# Asset ID: ICP
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: MANTA
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 200000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
# Asset ID: STRK
# Max Long Position Size: 1000000000000000000000000000000000000
# Max Short Position Size: 1000000000000000000000000000000000000
# Increase Position Fee Rate BPS: 5
# Decrease Position Fee Rate BPS: 5
# Initial Margin Fraction BPS: 100
# Maintenance Margin Fraction BPS: 50
# Max Profit Rate BPS: 400000
# Asset Class: 0
# Allow Increase Position: True
# Active: True
# Max Skew Scale USD: 50000000000000000000000000000000000000
# Max Funding Rate: 8000000000000000000
# --------------------
