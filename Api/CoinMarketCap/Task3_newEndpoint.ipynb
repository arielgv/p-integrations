# %%
import requests
import csv
import os
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor
from sources import api
import time
import json
import random

API_KEY = api

def fetch_historical_quotes_data(cryptocurrency_id, date, output_dir):
    url = "https://pro-api.coinmarketcap.com/v2/cryptocurrency/quotes/historical"
    headers = {
        'X-CMC_PRO_API_KEY': API_KEY
    }
    time_start = date.strftime('%Y-%m-%dT00:00:00Z')
    time_end = date.strftime('%Y-%m-%dT23:59:59Z')
    params = {
        'id': cryptocurrency_id,
        'time_start': time_start,
        'time_end': time_end,
        'interval': '15m',
        'count': 288,
        'convert': 'USD,ETH,BTC'
    }

    print(f"Sending request to API for cryptocurrency ID {cryptocurrency_id} on {date}")
    response = requests.get(url, headers=headers, params=params)
    print("***************")
    #print(response.text)
    print("***************")
    
    if response.status_code == 200:
        print(f"Received response from API for cryptocurrency ID {cryptocurrency_id} on {date}")
        json_data = response.json()['data']
        print(json.dumps(json_data, indent=2))
        if 'quotes' in json_data:
            quotes = json_data['quotes']
            print(f"Retrieved {len(quotes)} quotes for cryptocurrency ID {cryptocurrency_id} on {date}")
            return quotes
        else:
            print(f"No data found for cryptocurrency ID {cryptocurrency_id} on {date}")
            return []
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return []

def save_to_csv(data, output_dir, symbol, date):
    output_subdir = os.path.join(output_dir, symbol)
    os.makedirs(output_subdir, exist_ok=True)
    output_path = os.path.join(output_subdir, f"{date}.csv")

    #print(f"Saving data to CSV file: {output_path}")
    ##
    with open(output_path, 'w', newline='') as csvfile:
        fieldnames = ['timestamp', 'price_usd', 'volume_24h_usd', 'market_cap_usd',
                      'price_eth', 'volume_24h_eth', 'market_cap_eth',
                      'price_btc', 'volume_24h_btc', 'market_cap_btc']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        for quote in data:
            timestamp = quote['timestamp']
            quote_usd = quote['quote']['USD']
            quote_eth = quote['quote']['ETH']
            quote_btc = quote['quote']['BTC']

            row = {
                'timestamp': timestamp,
                'price_usd': quote_usd['price'],
                'volume_24h_usd': quote_usd['volume_24h'],
                'market_cap_usd': quote_usd['market_cap'],
                'price_eth': quote_eth['price'],
                'volume_24h_eth': quote_eth['volume_24h'],
                'market_cap_eth': quote_eth['market_cap'],
                'price_btc': quote_btc['price'],
                'volume_24h_btc': quote_btc['volume_24h'],
                'market_cap_btc': quote_btc['market_cap']
            }
            writer.writerow(row)
    print(f"Data saved to CSV file: {output_path}")

def backfill_data(cryptocurrency_id, start_date, end_date, output_dir, overwrite):
    current_date = start_date
    while current_date <= end_date:
        date_str = current_date.strftime('%Y-%m-%d')
        output_path = os.path.join(output_dir, str(cryptocurrency_id), f"{date_str}.csv")

        if not overwrite and os.path.exists(output_path):
            with open(output_path, 'r') as csvfile:
                reader = csv.reader(csvfile)
                row_count = sum(1 for row in reader) - 1  # Subtract 1 for the header row
                if row_count >= 288:
                    print(f"Skipping {cryptocurrency_id} - {date_str} (already exists with sufficient rows)")
                    current_date += timedelta(days=1)
                    continue

        print(f"Fetching data for {cryptocurrency_id} - {date_str}")
        data = fetch_historical_quotes_data(cryptocurrency_id, current_date, output_dir)
        save_to_csv(data, output_dir, str(cryptocurrency_id), date_str)
        current_date += timedelta(days=1)
        print(f"Waiting for 5 second before the next request...")
        time.sleep(5)

def main(watchlist_file, start_date, end_date, output_dir, overwrite):
    with open(watchlist_file, 'r') as file:
        watchlist = [line.strip() for line in file]

    print(f"Starting data backfill for {len(watchlist)} cryptocurrencies from {start_date} to {end_date}")
    with ThreadPoolExecutor() as executor:
        futures = []
        for cryptocurrency_id in watchlist:
            futures.append(executor.submit(backfill_data, cryptocurrency_id, start_date, end_date, output_dir, overwrite))

        for future in futures:
            future.result()
    print("Data backfill completed.")

if __name__ == '__main__':
    watchlist_file = 'watchlist.csv'
    start_date = datetime(2024, 3, 7)
    end_date = datetime(2024, 3, 8)
    output_dir = 'historical_data'
    overwrite = False

    main(watchlist_file, start_date, end_date, output_dir, overwrite)
    # watchlist : 1,1027,825
# Out:
# Starting data backfill for 3 cryptocurrencies from 2024-03-07 00:00:00 to 2024-03-08 00:00:00
# Fetching data for 1839 - 2024-03-07
# Sending request to API for cryptocurrency ID 1839 on 2024-03-07 00:00:00
# Fetching data for 1 - 2024-03-07
# Sending request to API for cryptocurrency ID 1 on 2024-03-07 00:00:00
# Fetching data for 825 - 2024-03-07
# Sending request to API for cryptocurrency ID 825 on 2024-03-07 00:00:00
# ***************
# ***************
# Received response from API for cryptocurrency ID 1 on 2024-03-07 00:00:00
# {
#   "quotes": [
#     {
#       "timestamp": "2024-03-07T00:15:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 2.918657632610308e-06,
#           "percent_change_24h": 6.024025509505337e-05,
#           "percent_change_7d": 0.00011086008858213444,
#           "percent_change_30d": 0.0008386706291381795,
#           "price": 1,
#           "volume_24h": 1028853.7611246388,
#           "market_cap": 19646718,
#           "total_supply": 296.4320770744754,
#           "circulating_supply": 296.4320770744754,
#           "timestamp": "2024-03-07T00:15:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 5.038901431339677e-05,
#           "percent_change_24h": 0.0010400147801893976,
#           "percent_change_7d": 0.0019139382872233762,
#           "percent_change_30d": 0.014479185863973386,
#           "price": 17.26444847466787,
#           "volume_24h": 17762592.74690457,
#           "market_cap": 339189750.6073298,
#           "total_supply": 5117.736320891056,
#           "circulating_supply": 5117.736320891056,
#           "timestamp": "2024-03-07T00:15:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.193440750449,
#           "percent_change_24h": 3.992561519593,
#           "percent_change_7d": 7.347507460473,
#           "percent_change_30d": 55.584825732003,
#           "price": 66277.30100566671,
#           "volume_24h": 68189650416.87,
#           "market_cap": 1302131442659.4502,
#           "total_supply": 19646718,
#           "circulating_supply": 19646718,
#           "timestamp": "2024-03-07T00:15:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T00:30:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -5.749191280907886e-06,
#           "percent_change_24h": 4.166086371553907e-05,
#           "percent_change_7d": 0.00010241724539849847,
#           "percent_change_30d": 0.000830522809691376,
#           "price": 1,
#           "volume_24h": 1030172.5732545078,
#           "market_cap": 19646718,
#           "total_supply": 298.3524160675818,
#           "circulating_supply": 298.3524160675818,
#           "timestamp": "2024-03-07T00:30:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -9.944152994281677e-05,
#           "percent_change_24h": 0.000720591788338998,
#           "percent_change_7d": 0.0017714713387214534,
#           "percent_change_30d": 0.01436523065815881,
#           "price": 17.296611833571387,
#           "volume_24h": 17818495.121174607,
#           "market_cap": 339821655.04964,
#           "total_supply": 5160.48593032915,
#           "circulating_supply": 5160.48593032915,
#           "timestamp": "2024-03-07T00:30:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.378588319521,
#           "percent_change_24h": 2.74339739508,
#           "percent_change_7d": 6.744248178722,
#           "percent_change_30d": 54.69051549721,
#           "price": 65850.70856456443,
#           "volume_24h": 67837593892.59,
#           "market_cap": 1293750301268.1821,
#           "total_supply": 19646718,
#           "circulating_supply": 19646718,
#           "timestamp": "2024-03-07T00:30:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T00:45:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 3.833451499346555e-06,
#           "percent_change_24h": 5.5652835607694876e-05,
#           "percent_change_7d": 0.00011114742197186301,
#           "percent_change_30d": 0.0008381722995064848,
#           "price": 1,
#           "volume_24h": 1025253.2782613218,
#           "market_cap": 19646718,
#           "total_supply": 296.9212034867435,
#           "circulating_supply": 296.9212034867435,
#           "timestamp": "2024-03-07T00:45:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 6.593923579120479e-05,
#           "percent_change_24h": 0.0009572849559230064,
#           "percent_change_7d": 0.0019118478650992446,
#           "percent_change_30d": 0.014417409715561916,
#           "price": 17.20100953473513,
#           "volume_24h": 17635391.414891448,
#           "market_cap": 337943383.64425236,
#           "total_supply": 5107.344452240504,
#           "circulating_supply": 5107.344452240504,
#           "timestamp": "2024-03-07T00:45:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.25365228111,
#           "percent_change_24h": 3.682443538033,
#           "percent_change_7d": 7.354416021036,
#           "percent_change_30d": 55.460285794479,
#           "price": 66168.12059660522,
#           "volume_24h": 67839082558.06,
#           "market_cap": 1299986405951.4946,
#           "total_supply": 19646718,
#           "circulating_supply": 19646718,
#           "timestamp": "2024-03-07T00:45:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T01:00:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 3.8661765319251015e-06,
#           "percent_change_24h": 6.550816214225922e-05,
#           "percent_change_7d": 0.00012080076515095426,
#           "percent_change_30d": 0.0008406795966848106,
#           "price": 1,
#           "volume_24h": 1021161.9092596323,
#           "market_cap": 19646718,
#           "total_supply": 296.5155742806905,
#           "circulating_supply": 296.5155742806905,
#           "timestamp": "2024-03-07T01:00:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 6.668047305038203e-05,
#           "percent_change_24h": 0.0011298281918161505,
#           "percent_change_7d": 0.002083467244343043,
#           "percent_change_30d": 0.014499315467841532,
#           "price": 17.247136156294328,
#           "volume_24h": 17612118.486622356,
#           "market_cap": 338849620.37031865,
#           "total_supply": 5114.044482080873,
#           "circulating_supply": 5114.044482080873,
#           "timestamp": "2024-03-07T01:00:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.25616759,
#           "percent_change_24h": 4.340481579861,
#           "percent_change_7d": 8.004094128487,
#           "percent_change_30d": 55.702284793935,
#           "price": 66258.63767075463,
#           "volume_24h": 67660796948.81,
#           "market_cap": 1301764769381.4932,
#           "total_supply": 19646718,
#           "circulating_supply": 19646718,
#           "timestamp": "2024-03-07T01:00:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T01:15:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -1.0115349092008717e-05,
#           "percent_change_24h": 5.500801212983086e-05,
#           "percent_change_7d": 0.00011701166289085002,
#           "percent_change_30d": 0.000831736798615063,
#           "price": 1,
#           "volume_24h": 1023830.7717484321,
#           "market_cap": 19646718,
#           "total_supply": 298.41941118529866,
#           "circulating_supply": 298.41941118529866,
#           "timestamp": "2024-03-07T01:15:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -0.00017517542550687476,
#           "percent_change_24h": 0.0009526168443107,
#           "percent_change_7d": 0.002026382643814541,
#           "percent_change_30d": 0.014403837799550052,
#           "price": 17.31778349056347,
#           "volume_24h": 17730479.636115853,
#           "market_cap": 340237608.6241562,
#           "total_supply": 5167.962752288437,
#           "circulating_supply": 5167.962752288437,
#           "timestamp": "2024-03-07T01:15:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.665953365074,
#           "percent_change_24h": 3.621503365893,
#           "percent_change_7d": 7.703571072661,
#           "percent_change_30d": 54.758161567668,
#           "price": 65835.92508933909,
#           "volume_24h": 67404845992.99,
#           "market_cap": 1293459854499.3699,
#           "total_supply": 19646718,
#           "circulating_supply": 19646718,
#           "timestamp": "2024-03-07T01:15:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T01:30:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 7.007520381816713e-06,
#           "percent_change_24h": 6.592374799790724e-05,
#           "percent_change_7d": 0.0001224011520300429,
#           "percent_change_30d": 0.000832553128531546,
#           "price": 1,
#           "volume_24h": 1020480.995624164,
#           "market_cap": 19646718,
#           "total_supply": 296.9756682993743,
#           "circulating_supply": 296.9756682993743,
#           "timestamp": "2024-03-07T01:30:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 0.00012163236239581494,
#           "percent_change_24h": 0.0011442651280441987,
#           "percent_change_7d": 0.0021245662474296922,
#           "percent_change_30d": 0.014450961014124835,
#           "price": 17.357404012898716,
#           "volume_24h": 17712900.92853374,
#           "market_cap": 341016021.8534894,
#           "total_supply": 5154.726656672838,
#           "circulating_supply": 5154.726656672838,
#           "timestamp": "2024-03-07T01:30:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.463589416632,
#           "percent_change_24h": 4.361250515353,
#           "percent_change_7d": 8.097568836465,
#           "percent_change_30d": 55.078372682667,
#           "price": 66155.9854802468,
#           "volume_24h": 67510925929.38,
#           "market_cap": 1299747990742.5034,
#           "total_supply": 19646718,
#           "circulating_supply": 19646718,
#           "timestamp": "2024-03-07T01:30:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T01:45:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -3.3713176228382183e-06,
#           "percent_change_24h": 6.615326818238141e-05,
#           "percent_change_7d": 0.00011162075454576923,
#           "percent_change_30d": 0.0008285631965438359,
#           "price": 1,
#           "volume_24h": 1018698.9700669795,
#           "market_cap": 19646718,
#           "total_supply": 297.58355675298566,
#           "circulating_supply": 297.58355675298566,
#           "timestamp": "2024-03-07T01:45:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -5.8450380998933e-05,
#           "percent_change_24h": 0.0011469354603051412,
#           "percent_change_7d": 0.0019352301860825528,
#           "percent_change_30d": 0.01436525416401119,
#           "price": 17.337547967291574,
#           "volume_24h": 17661742.25776678,
#           "market_cap": 340625915.7248507,
#           "total_supply": 5159.369189482123,
#           "circulating_supply": 5159.369189482123,
#           "timestamp": "2024-03-07T01:45:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.22257723964,
#           "percent_change_24h": 4.367494692714,
#           "percent_change_7d": 7.369296581559,
#           "percent_change_30d": 54.702442719937,
#           "price": 66020.84542025988,
#           "volume_24h": 67255367232.57,
#           "market_cap": 1297092932093.4373,
#           "total_supply": 19646718,
#           "circulating_supply": 19646718,
#           "timestamp": "2024-03-07T01:45:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T02:00:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 3.348256899863568e-06,
#           "percent_change_24h": 7.756434110973153e-05,
#           "percent_change_7d": 0.00012326312720508907,
#           "percent_change_30d": 0.0008396783926750034,
#           "price": 1,
#           "volume_24h": 1012105.905268115,
#           "market_cap": 19646718,
#           "total_supply": 295.8577516896601,
#           "circulating_supply": 295.8577516896601,
#           "timestamp": "2024-03-07T02:00:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 5.803811213244579e-05,
#           "percent_change_24h": 0.0013444870156137973,
#           "percent_change_7d": 0.0021366219535951356,
#           "percent_change_30d": 0.014554841568832258,
#           "price": 17.333828875200908,
#           "volume_24h": 17543670.565497804,
#           "market_cap": 340552847.7713294,
#           "total_supply": 5128.3476391902495,
#           "circulating_supply": 5128.3476391902495,
#           "timestamp": "2024-03-07T02:00:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.222344213486,
#           "percent_change_24h": 5.150734526764,
#           "percent_change_7d": 8.185406284493,
#           "percent_change_30d": 55.759649687609,
#           "price": 66405.9599175499,
#           "volume_24h": 67209864177.55,
#           "market_cap": 1304659168019.4062,
#           "total_supply": 19646718,
#           "circulating_supply": 19646718,
#           "timestamp": "2024-03-07T02:00:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T02:15:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 1.1878444065183812e-05,
#           "percent_change_24h": 6.825540955332146e-05,
#           "percent_change_7d": 0.0001234079389276211,
#           "percent_change_30d": 0.0008327287020816117,
#           "price": 1,
#           "volume_24h": 1013330.7335496652,
#           "market_cap": 19646812,
#           "total_supply": 296.08710340317793,
#           "circulating_supply": 296.08710340317793,
#           "timestamp": "2024-03-07T02:15:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 0.0002064513963059128,
#           "percent_change_24h": 0.0011863022236235196,
#           "percent_change_7d": 0.002144871934996811,
#           "percent_change_30d": 0.014473107954656929,
#           "price": 17.380339981650458,
#           "volume_24h": 17612032.662948433,
#           "market_cap": 341468272.11557,
#           "total_supply": 5146.094521329327,
#           "circulating_supply": 5146.094521329327,
#           "timestamp": "2024-03-07T02:15:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.788192240455,
#           "percent_change_24h": 4.529076694202,
#           "percent_change_7d": 8.188713887065,
#           "percent_change_30d": 55.255578742731,
#           "price": 66354.83874232507,
#           "volume_24h": 67239397417.33,
#           "market_cap": 1303661042060.777,
#           "total_supply": 19646812,
#           "circulating_supply": 19646812,
#           "timestamp": "2024-03-07T02:15:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T02:30:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -3.956306637286979e-06,
#           "percent_change_24h": 6.650967763805458e-05,
#           "percent_change_7d": 0.00011560253518432216,
#           "percent_change_30d": 0.0008270454570351458,
#           "price": 1,
#           "volume_24h": 1018456.182277022,
#           "market_cap": 19646812,
#           "total_supply": 297.7543773108289,
#           "circulating_supply": 297.7543773108289,
#           "timestamp": "2024-03-07T02:30:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -6.890053521537816e-05,
#           "percent_change_24h": 0.0011582904982831905,
#           "percent_change_7d": 0.002013260668772732,
#           "percent_change_30d": 0.014403300821051889,
#           "price": 17.415367799353998,
#           "volume_24h": 17736789.00188026,
#           "market_cap": 342156457.06476176,
#           "total_supply": 5185.5019947357105,
#           "circulating_supply": 5185.5019947357105,
#           "timestamp": "2024-03-07T02:30:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.261050109218,
#           "percent_change_24h": 4.388527028677,
#           "percent_change_7d": 7.627835049823,
#           "percent_change_30d": 54.571176271445,
#           "price": 65983.28520789633,
#           "volume_24h": 67201084746.93,
#           "market_cap": 1296361199621.9202,
#           "total_supply": 19646812,
#           "circulating_supply": 19646812,
#           "timestamp": "2024-03-07T02:30:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T02:45:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 2.556974601606188e-06,
#           "percent_change_24h": 6.395680050442591e-05,
#           "percent_change_7d": 0.00011413524630732759,
#           "percent_change_30d": 0.0008216509810057146,
#           "price": 1,
#           "volume_24h": 1016187.0731681654,
#           "market_cap": 19646812,
#           "total_supply": 297.08261655285526,
#           "circulating_supply": 297.08261655285526,
#           "timestamp": "2024-03-07T02:45:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 4.467234982302005e-05,
#           "percent_change_24h": 0.001117375418551324,
#           "percent_change_7d": 0.0019940321843536124,
#           "percent_change_30d": 0.014354886447780215,
#           "price": 17.470783556066095,
#           "volume_24h": 17753584.40779332,
#           "market_cap": 343245200.01872206,
#           "total_supply": 5190.266092064713,
#           "circulating_supply": 5190.266092064713,
#           "timestamp": "2024-03-07T02:45:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.169099087215,
#           "percent_change_24h": 4.229622218264,
#           "percent_change_7d": 7.5480475862,
#           "percent_change_30d": 54.337822053492,
#           "price": 66132.48606723695,
#           "volume_24h": 67202977458,
#           "market_cap": 1299292520855.6238,
#           "total_supply": 19646812,
#           "circulating_supply": 19646812,
#           "timestamp": "2024-03-07T02:45:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T03:00:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -6.292845794284244e-06,
#           "percent_change_24h": 7.85609472532215e-05,
#           "percent_change_7d": 0.0001075386330938002,
#           "percent_change_30d": 0.0008241019827003961,
#           "price": 1,
#           "volume_24h": 1013638.817713621,
#           "market_cap": 19646812,
#           "total_supply": 297.0955108079087,
#           "circulating_supply": 297.0955108079087,
#           "timestamp": "2024-03-07T03:00:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -0.00010992469964227502,
#           "percent_change_24h": 0.001372318472870704,
#           "percent_change_7d": 0.001878506534120682,
#           "percent_change_30d": 0.014395579660513214,
#           "price": 17.46820170647102,
#           "volume_24h": 17706447.325330343,
#           "market_cap": 343194474.90511537,
#           "total_supply": 5189.72430887959,
#           "circulating_supply": 5189.72430887959,
#           "timestamp": "2024-03-07T03:00:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.416143474969,
#           "percent_change_24h": 5.195205262539,
#           "percent_change_7d": 7.111488495351,
#           "percent_change_30d": 54.497547535851,
#           "price": 66129.6158483624,
#           "volume_24h": 67031545624.39,
#           "market_cap": 1299236130204.9966,
#           "total_supply": 19646812,
#           "circulating_supply": 19646812,
#           "timestamp": "2024-03-07T03:00:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T03:15:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 1.2513522695327842e-09,
#           "percent_change_24h": 8.370104170155886e-05,
#           "percent_change_7d": 0.00011579257537727766,
#           "percent_change_30d": 0.0008244159701542598,
#           "price": 1,
#           "volume_24h": 1007334.6968548058,
#           "market_cap": 19646812,
#           "total_supply": 296.0868575523511,
#           "circulating_supply": 296.0868575523511,
#           "timestamp": "2024-03-07T03:15:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 2.1812675375405727e-08,
#           "percent_change_24h": 0.001459016534090018,
#           "percent_change_7d": 0.0020184131351995635,
#           "percent_change_30d": 0.014370627975117853,
#           "price": 17.431282866134808,
#           "volume_24h": 17559136.041748278,
#           "market_cap": 342469137.38977176,
#           "total_supply": 5161.173766939995,
#           "circulating_supply": 5161.173766939995,
#           "timestamp": "2024-03-07T03:15:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 8.3033347e-05,
#           "percent_change_24h": 5.553973736318,
#           "percent_change_7d": 7.6834040465,
#           "percent_change_30d": 54.704034178736,
#           "price": 66354.89383896835,
#           "volume_24h": 66841586870.11,
#           "market_cap": 1303662124534.1694,
#           "total_supply": 19646812,
#           "circulating_supply": 19646812,
#           "timestamp": "2024-03-07T03:15:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T03:30:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 6.485869277561465e-06,
#           "percent_change_24h": 7.104785903775506e-05,
#           "percent_change_7d": 0.00012074368630935464,
#           "percent_change_30d": 0.0008246643985521107,
#           "price": 1,
#           "volume_24h": 1006662.7355579274,
#           "market_cap": 19646812,
#           "total_supply": 296.48011076729944,
#           "circulating_supply": 296.48011076729944,
#           "timestamp": "2024-03-07T03:30:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 0.0001132234069998808,
#           "percent_change_24h": 0.0012402779513506262,
#           "percent_change_7d": 0.002107814843719757,
#           "percent_change_30d": 0.014396113896190483,
#           "price": 17.45693632642102,
#           "volume_24h": 17573247.27681554,
#           "market_cap": 342973146.1011644,
#           "total_supply": 5175.634415714998,
#           "circulating_supply": 5175.634415714998,
#           "timestamp": "2024-03-07T03:30:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.429798322805,
#           "percent_change_24h": 4.708119967659,
#           "percent_change_7d": 8.00130740294,
#           "percent_change_30d": 54.647936954405,
#           "price": 66266.88026105177,
#           "volume_24h": 66708398960.48,
#           "market_cap": 1301932938315.395,
#           "total_supply": 19646812,
#           "circulating_supply": 19646812,
#           "timestamp": "2024-03-07T03:30:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T03:45:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -5.544634846353213e-06,
#           "percent_change_24h": 6.652753211937544e-05,
#           "percent_change_7d": 0.00010991632460407342,
#           "percent_change_30d": 0.0008196105886366509,
#           "price": 1,
#           "volume_24h": 1010989.6098458177,
#           "market_cap": 19646812,
#           "total_supply": 298.17196053720346,
#           "circulating_supply": 298.17196053720346,
#           "timestamp": "2024-03-07T03:45:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -9.692550601827036e-05,
#           "percent_change_24h": 0.001162964720581786,
#           "percent_change_7d": 0.0019214422008196565,
#           "percent_change_30d": 0.014327574897703034,
#           "price": 17.48095387778686,
#           "volume_24h": 17673062.74063647,
#           "market_cap": 343445014.4175494,
#           "total_supply": 5212.330289800137,
#           "circulating_supply": 5212.330289800137,
#           "timestamp": "2024-03-07T03:45:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.365340853106,
#           "percent_change_24h": 4.383557441211,
#           "percent_change_7d": 7.242483033403,
#           "percent_change_30d": 54.004860548061,
#           "price": 65890.877078459,
#           "volume_24h": 66614992109.95,
#           "market_cap": 1294545674475.5933,
#           "total_supply": 19646812,
#           "circulating_supply": 19646812,
#           "timestamp": "2024-03-07T03:45:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T04:00:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -5.905933691670347e-06,
#           "percent_change_24h": 6.14624585941676e-05,
#           "percent_change_7d": 0.00010638574304651634,
#           "percent_change_30d": 0.0008178429403989709,
#           "price": 1,
#           "volume_24h": 1010695.395729983,
#           "market_cap": 19646812,
#           "total_supply": 298.2558384971571,
#           "circulating_supply": 298.2558384971571,
#           "timestamp": "2024-03-07T04:00:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -0.00010302276340897307,
#           "percent_change_24h": 0.001072147548695196,
#           "percent_change_7d": 0.0018557867067534324,
#           "percent_change_30d": 0.014266404628493585,
#           "price": 17.443941768983123,
#           "volume_24h": 17630511.629293177,
#           "market_cap": 342717844.4741589,
#           "total_supply": 5202.757479003642,
#           "circulating_supply": 5202.757479003642,
#           "timestamp": "2024-03-07T04:00:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.389037711749,
#           "percent_change_24h": 4.0486763818,
#           "percent_change_7d": 7.007878550331,
#           "percent_change_30d": 53.873233719443,
#           "price": 65872.34670407725,
#           "volume_24h": 66576877519.74,
#           "market_cap": 1294181611693.8254,
#           "total_supply": 19646812,
#           "circulating_supply": 19646812,
#           "timestamp": "2024-03-07T04:00:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T04:15:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -8.51827599052913e-06,
#           "percent_change_24h": 5.8309080860865286e-05,
#           "percent_change_7d": 0.00010961133362616259,
#           "percent_change_30d": 0.0008204713292262947,
#           "price": 1,
#           "volume_24h": 1008442.8708010664,
#           "market_cap": 19646943,
#           "total_supply": 297.7624126134744,
#           "circulating_supply": 297.7624126134744,
#           "timestamp": "2024-03-07T04:15:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -0.00014837144322985379,
#           "percent_change_24h": 0.001015628337277603,
#           "percent_change_7d": 0.001909211650637364,
#           "percent_change_30d": 0.014290980402768105,
#           "price": 17.418013151348646,
#           "volume_24h": 17565071.185996756,
#           "market_cap": 342210711.5577972,
#           "total_supply": 5186.4296188787985,
#           "circulating_supply": 5186.4296188787985,
#           "timestamp": "2024-03-07T04:15:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.562052414122,
#           "percent_change_24h": 3.847346540488,
#           "percent_change_7d": 7.232368938059,
#           "percent_change_30d": 54.136293755009,
#           "price": 65981.94455625839,
#           "volume_24h": 66539021589.35,
#           "market_cap": 1296343503725.9688,
#           "total_supply": 19646943,
#           "circulating_supply": 19646943,
#           "timestamp": "2024-03-07T04:15:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T04:30:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -2.703363379861488e-06,
#           "percent_change_24h": 6.456284574513653e-05,
#           "percent_change_7d": 0.00010777835079048532,
#           "percent_change_30d": 0.0008210750097080345,
#           "price": 1,
#           "volume_24h": 1005781.147383241,
#           "market_cap": 19646943,
#           "total_supply": 297.01321588441823,
#           "circulating_supply": 297.01321588441823,
#           "timestamp": "2024-03-07T04:30:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -4.706966605193252e-05,
#           "percent_change_24h": 0.001124137291798972,
#           "percent_change_7d": 0.0018765849301384376,
#           "percent_change_30d": 0.014296164103741252,
#           "price": 17.41152018355158,
#           "volume_24h": 17512178.74789897,
#           "market_cap": 342083144.58958745,
#           "total_supply": 5171.451603153111,
#           "circulating_supply": 5171.451603153111,
#           "timestamp": "2024-03-07T04:30:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.178823107498,
#           "percent_change_24h": 4.270727639157,
#           "percent_change_7d": 7.129363278699,
#           "percent_change_30d": 54.312781558972,
#           "price": 66148.37976652711,
#           "volume_24h": 66530793299.12,
#           "market_cap": 1299613446815.3115,
#           "total_supply": 19646943,
#           "circulating_supply": 19646943,
#           "timestamp": "2024-03-07T04:30:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T04:45:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 4.703811934681364e-06,
#           "percent_change_24h": 5.722679499970847e-05,
#           "percent_change_7d": 9.58138401131993e-05,
#           "percent_change_30d": 0.0008240834712788547,
#           "price": 1,
#           "volume_24h": 1006510.7315915278,
#           "market_cap": 19646943,
#           "total_supply": 297.2497934231934,
#           "circulating_supply": 297.2497934231934,
#           "timestamp": "2024-03-07T04:45:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 8.182428679291287e-05,
#           "percent_change_24h": 0.0009954780827377131,
#           "percent_change_7d": 0.001666711858598954,
#           "percent_change_30d": 0.01433519095396995,
#           "price": 17.395314253450405,
#           "volume_24h": 17508570.4755049,
#           "market_cap": 341764747.60462767,
#           "total_supply": 5170.753568369665,
#           "circulating_supply": 5170.753568369665,
#           "timestamp": "2024-03-07T04:45:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.310901898027,
#           "percent_change_24h": 3.782446966519,
#           "percent_change_7d": 6.332886000143,
#           "percent_change_30d": 54.468401141686,
#           "price": 66095.73306592251,
#           "volume_24h": 66526064643.26,
#           "market_cap": 1298579100089.3948,
#           "total_supply": 19646943,
#           "circulating_supply": 19646943,
#           "timestamp": "2024-03-07T04:45:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T05:00:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -2.9331930545684606e-07,
#           "percent_change_24h": 2.910699189980246e-05,
#           "percent_change_7d": 8.252541419809715e-05,
#           "percent_change_30d": 0.0008192377846931459,
#           "price": 1,
#           "volume_24h": 1001590.9581328961,
#           "market_cap": 19646943,
#           "total_supply": 298.3154554688079,
#           "circulating_supply": 298.3154554688079,
#           "timestamp": "2024-03-07T05:00:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -5.110075866140187e-06,
#           "percent_change_24h": 0.0005070888075759519,
#           "percent_change_7d": 0.0014377203259093433,
#           "percent_change_30d": 0.01427238901193466,
#           "price": 17.421546318546003,
#           "volume_24h": 17449263.26934912,
#           "market_cap": 342280127.4923332,
#           "total_supply": 5197.116524987984,
#           "circulating_supply": 5197.116524987984,
#           "timestamp": "2024-03-07T05:00:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.019317898451,
#           "percent_change_24h": 1.91697547101,
#           "percent_change_7d": 5.435092547429,
#           "percent_change_30d": 53.954690460198,
#           "price": 65859.62155103392,
#           "volume_24h": 65964401451.57,
#           "market_cap": 1293940230614.735,
#           "total_supply": 19646943,
#           "circulating_supply": 19646943,
#           "timestamp": "2024-03-07T05:00:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T05:15:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 1.9923881588171977e-06,
#           "percent_change_24h": 1.5423175239457952e-05,
#           "percent_change_7d": 9.795592710480153e-05,
#           "percent_change_30d": 0.000825891865163718,
#           "price": 1,
#           "volume_24h": 981141.6755278154,
#           "market_cap": 19646943,
#           "total_supply": 297.3709692475723,
#           "circulating_supply": 297.3709692475723,
#           "timestamp": "2024-03-07T05:15:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 3.46613270938948e-05,
#           "percent_change_24h": 0.0002683150466617283,
#           "percent_change_7d": 0.0017041269870730843,
#           "percent_change_30d": 0.014367937269623666,
#           "price": 17.39687467048181,
#           "volume_24h": 17068798.763143934,
#           "market_cap": 341795405.0290999,
#           "total_supply": 5173.325482639716,
#           "circulating_supply": 5173.325482639716,
#           "timestamp": "2024-03-07T05:15:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.131634694164,
#           "percent_change_24h": 1.018990675436,
#           "percent_change_7d": 6.471830526059,
#           "percent_change_30d": 54.565684202772,
#           "price": 66068.79968717859,
#           "volume_24h": 64822852825.19,
#           "market_cap": 1298049941532.4155,
#           "total_supply": 19646943,
#           "circulating_supply": 19646943,
#           "timestamp": "2024-03-07T05:15:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T05:30:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -1.7864054414115203e-06,
#           "percent_change_24h": 5.488106827722857e-06,
#           "percent_change_7d": 9.51563894686587e-05,
#           "percent_change_30d": 0.0008258081284312228,
#           "price": 1,
#           "volume_24h": 967000.7868122808,
#           "market_cap": 19646943,
#           "total_supply": 297.36418994324157,
#           "circulating_supply": 297.36418994324157,
#           "timestamp": "2024-03-07T05:30:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -3.106243039357027e-05,
#           "percent_change_24h": 9.542846902320213e-05,
#           "percent_change_7d": 0.0016546012768737263,
#           "percent_change_30d": 0.014359342461233713,
#           "price": 17.38823095446151,
#           "volume_24h": 16814433.014237937,
#           "market_cap": 341625582.4331409,
#           "total_supply": 5170.637212319444,
#           "circulating_supply": 5170.637212319444,
#           "timestamp": "2024-03-07T05:30:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.118028354016,
#           "percent_change_24h": 0.362600897044,
#           "percent_change_7d": 6.287011762692,
#           "percent_change_30d": 54.561395678887,
#           "price": 66070.30592268036,
#           "volume_24h": 63890037812.16,
#           "market_cap": 1298079534455.4634,
#           "total_supply": 19646943,
#           "circulating_supply": 19646943,
#           "timestamp": "2024-03-07T05:30:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T05:45:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -7.0266814484124945e-06,
#           "percent_change_24h": -5.794406642767615e-06,
#           "percent_change_7d": 8.891507980243355e-05,
#           "percent_change_30d": 0.000819942886399138,
#           "price": 1,
#           "volume_24h": 957342.3620270849,
#           "market_cap": 19646943,
#           "total_supply": 298.63032152215334,
#           "circulating_supply": 298.63032152215334,
#           "timestamp": "2024-03-07T05:45:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -0.00012299623602610326,
#           "percent_change_24h": -0.0001014262866898685,
#           "percent_change_7d": 0.0015563847915904445,
#           "percent_change_30d": 0.01435242077271872,
#           "price": 17.504171340212274,
#           "volume_24h": 16757484.736165622,
#           "market_cap": 343903456.58338416,
#           "total_supply": 5227.276315306453,
#           "circulating_supply": 5227.276315306453,
#           "timestamp": "2024-03-07T05:45:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.462286646555,
#           "percent_change_24h": -0.381215063658,
#           "percent_change_7d": 5.849739222108,
#           "percent_change_30d": 53.944191166617,
#           "price": 65790.18131801639,
#           "volume_24h": 62983727581.18,
#           "market_cap": 1292575942314.733,
#           "total_supply": 19646943,
#           "circulating_supply": 19646943,
#           "timestamp": "2024-03-07T05:45:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T06:00:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -7.253026892077593e-07,
#           "percent_change_24h": -1.3131856205645215e-05,
#           "percent_change_7d": 8.095902720347142e-05,
#           "percent_change_30d": 0.0008207027235217814,
#           "price": 1,
#           "volume_24h": 951237.2145805544,
#           "market_cap": 19646943,
#           "total_supply": 298.457955274735,
#           "circulating_supply": 298.457955274735,
#           "timestamp": "2024-03-07T06:00:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -1.2712503481484888e-05,
#           "percent_change_24h": -0.00023016427515933966,
#           "percent_change_7d": 0.001418982626833958,
#           "percent_change_30d": 0.01438459609384716,
#           "price": 17.527169925938956,
#           "volume_24h": 16672496.299830234,
#           "market_cap": 344355308.48623693,
#           "total_supply": 5231.123297848569,
#           "circulating_supply": 5231.123297848569,
#           "timestamp": "2024-03-07T06:00:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.047745353544,
#           "percent_change_24h": -0.864446149941,
#           "percent_change_7d": 5.329385143505,
#           "percent_change_30d": 54.025363854465,
#           "price": 65828.17664188142,
#           "volume_24h": 62618211389.74,
#           "market_cap": 1293322434276.9758,
#           "total_supply": 19646943,
#           "circulating_supply": 19646943,
#           "timestamp": "2024-03-07T06:00:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T06:15:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -2.746394665012942e-06,
#           "percent_change_24h": -9.087782580047504e-06,
#           "percent_change_7d": 6.721952107996511e-05,
#           "percent_change_30d": 0.0008258032007751789,
#           "price": 1,
#           "volume_24h": 937138.0532714761,
#           "market_cap": 19647050,
#           "total_supply": 297.91217430450394,
#           "circulating_supply": 297.91217430450394,
#           "timestamp": "2024-03-07T06:15:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -4.818644750228955e-05,
#           "percent_change_24h": -0.00015944829917721127,
#           "percent_change_7d": 0.0011793898251085922,
#           "percent_change_30d": 0.014489003743090333,
#           "price": 17.545347038482713,
#           "volume_24h": 16442412.36761615,
#           "market_cap": 344714310.5324218,
#           "total_supply": 5226.972485161475,
#           "circulating_supply": 5226.972485161475,
#           "timestamp": "2024-03-07T06:15:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.18112235067,
#           "percent_change_24h": -0.59933139408,
#           "percent_change_7d": 4.433069224906,
#           "percent_change_30d": 54.461006213215,
#           "price": 65949.13432412544,
#           "volume_24h": 61803443355.45,
#           "market_cap": 1295705939522.8086,
#           "total_supply": 19647050,
#           "circulating_supply": 19647050,
#           "timestamp": "2024-03-07T06:15:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T06:30:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 1.8576200108920212e-06,
#           "percent_change_24h": 4.971447522311571e-06,
#           "percent_change_7d": 7.258338793761972e-05,
#           "percent_change_30d": 0.0008322842370704002,
#           "price": 1,
#           "volume_24h": 928606.1620158743,
#           "market_cap": 19647050,
#           "total_supply": 297.0008418978677,
#           "circulating_supply": 297.0008418978677,
#           "timestamp": "2024-03-07T06:30:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 3.25101797453323e-05,
#           "percent_change_24h": 8.700522797836657e-05,
#           "percent_change_7d": 0.0012702807756921634,
#           "percent_change_30d": 0.01456579385865491,
#           "price": 17.50098489180306,
#           "volume_24h": 16251522.411875041,
#           "market_cap": 343842725.2184993,
#           "total_supply": 5197.807246907372,
#           "circulating_supply": 5197.807246907372,
#           "timestamp": "2024-03-07T06:30:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.12288434269,
#           "percent_change_24h": 0.328868690806,
#           "percent_change_7d": 4.801499695648,
#           "percent_change_30d": 55.056847365965,
#           "price": 66151.49598382688,
#           "volume_24h": 61428686797.15,
#           "market_cap": 1299681749169.046,
#           "total_supply": 19647050,
#           "circulating_supply": 19647050,
#           "timestamp": "2024-03-07T06:30:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T06:45:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 5.743498730842442e-06,
#           "percent_change_24h": 5.088737912046963e-07,
#           "percent_change_7d": 6.248898650432239e-05,
#           "percent_change_30d": 0.0008290880347539729,
#           "price": 1,
#           "volume_24h": 925949.0203690983,
#           "market_cap": 19647050,
#           "total_supply": 297.50351983726216,
#           "circulating_supply": 297.50351983726216,
#           "timestamp": "2024-03-07T06:45:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 0.00010049969936988986,
#           "percent_change_24h": 8.904269928477334e-06,
#           "percent_change_7d": 0.0010934318351790344,
#           "percent_change_30d": 0.014507376452701932,
#           "price": 17.49799278795154,
#           "volume_24h": 16202249.280429274,
#           "market_cap": 343783939.2045233,
#           "total_supply": 5205.714444502611,
#           "circulating_supply": 5205.714444502611,
#           "timestamp": "2024-03-07T06:45:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.379299064433,
#           "percent_change_24h": 0.033605884142,
#           "percent_change_7d": 4.126755350563,
#           "percent_change_30d": 54.752744041897,
#           "price": 66039.72286024435,
#           "volume_24h": 61149416687.89,
#           "market_cap": 1297485737021.3638,
#           "total_supply": 19647050,
#           "circulating_supply": 19647050,
#           "timestamp": "2024-03-07T06:45:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T07:00:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 1.790051598370627e-06,
#           "percent_change_24h": 3.192733655352233e-06,
#           "percent_change_7d": 6.9755225392105e-05,
#           "percent_change_30d": 0.0008228765028657586,
#           "price": 1,
#           "volume_24h": 924795.7192655569,
#           "market_cap": 19647050,
#           "total_supply": 298.1078883859541,
#           "circulating_supply": 298.1078883859541,
#           "timestamp": "2024-03-07T07:00:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 3.127232167315233e-05,
#           "percent_change_24h": 5.577727143606165e-05,
#           "percent_change_7d": 0.0012186284735204009,
#           "percent_change_30d": 0.014375707783127618,
#           "price": 17.47006717662082,
#           "volume_24h": 16156243.340220649,
#           "market_cap": 343235283.32242805,
#           "total_supply": 5207.964835983199,
#           "circulating_supply": 5207.964835983199,
#           "timestamp": "2024-03-07T07:00:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.117974849462,
#           "percent_change_24h": 0.210419784941,
#           "percent_change_7d": 4.597276537901,
#           "percent_change_30d": 54.232364943988,
#           "price": 65905.83733417807,
#           "volume_24h": 60949436241.26,
#           "market_cap": 1294855281396.4631,
#           "total_supply": 19647050,
#           "circulating_supply": 19647050,
#           "timestamp": "2024-03-07T07:00:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T07:15:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 2.060899551439169e-07,
#           "percent_change_24h": -5.444545496762208e-06,
#           "percent_change_7d": 6.843932255092464e-05,
#           "percent_change_30d": 0.0008227085507961469,
#           "price": 1,
#           "volume_24h": 918666.7343247585,
#           "market_cap": 19647050,
#           "total_supply": 297.8716837079704,
#           "circulating_supply": 297.8716837079704,
#           "timestamp": "2024-03-07T07:15:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": 3.609430848613829e-06,
#           "percent_change_24h": -9.535501358604216e-05,
#           "percent_change_7d": 0.0011986367889741903,
#           "percent_change_30d": 0.014408803284897216,
#           "price": 17.51386110057275,
#           "volume_24h": 16089401.58268059,
#           "market_cap": 344095704.73600787,
#           "total_supply": 5216.883294255133,
#           "circulating_supply": 5216.883294255133,
#           "timestamp": "2024-03-07T07:15:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": 0.013593301662,
#           "percent_change_24h": -0.359111870825,
#           "percent_change_7d": 4.514127611547,
#           "percent_change_30d": 54.264292032425,
#           "price": 65958.09898889791,
#           "volume_24h": 60593511400.4,
#           "market_cap": 1295882068739.8267,
#           "total_supply": 19647050,
#           "circulating_supply": 19647050,
#           "timestamp": "2024-03-07T07:15:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T07:30:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -3.2323059016070834e-07,
#           "percent_change_24h": 1.0750922043715497e-06,
#           "percent_change_7d": 8.356706103023461e-05,
#           "percent_change_30d": 0.0008259156554101366,
#           "price": 1,
#           "volume_24h": 912027.6934838565,
#           "market_cap": 19647050,
#           "total_supply": 297.06434717353306,
#           "circulating_supply": 297.06434717353306,
#           "timestamp": "2024-03-07T07:30:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -5.647672436140715e-06,
#           "percent_change_24h": 1.8784634851299543e-05,
#           "percent_change_7d": 0.0014601321827710971,
#           "percent_change_30d": 0.014430877595210773,
#           "price": 17.4725802818747,
#           "volume_24h": 15935477.093689695,
#           "market_cap": 343284658.42700636,
#           "total_supply": 5190.4806548722545,
#           "circulating_supply": 5190.4806548722545,
#           "timestamp": "2024-03-07T07:30:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.021377616085,
#           "percent_change_24h": 0.071103754102,
#           "percent_change_7d": 5.526904329098,
#           "percent_change_30d": 54.623876382401,
#           "price": 66137.35437098071,
#           "volume_24h": 60319098760.09,
#           "market_cap": 1299403908194.3767,
#           "total_supply": 19647050,
#           "circulating_supply": 19647050,
#           "timestamp": "2024-03-07T07:30:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-07T07:45:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": 6.483104366496875e-06,
#           "percent_change_24h": 4.215136503740396e-06,
#           "percent_change_7d": 8.663343072826661e-05,
#           "percent_change_30d": 0.0008313857637399555,
#           "price": 1,
#           "volume_24h": 910951.8025021887,
#           "market_cap": 19647050,
#           "total_supply": 296.2297810808239,
#           "circulating_supply": 296.2297810808239,
#           "timestamp": "2024-03-07T07:45:00.000Z"
#         },
#         "ETH": {
# ...
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-08T21:30:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -4.104874756026543e-06,
#           "percent_change_24h": 3.2621900473629884e-05,
#           "percent_change_7d": 0.00013998431631109923,
#           "percent_change_30d": 0.0008047203480722575,
#           "price": 1,
#           "volume_24h": 842282.0587819912,
#           "market_cap": 19648637,
#           "total_supply": 285.09435529149204,
#           "circulating_supply": 285.09435529149204,
#           "timestamp": "2024-03-08T21:30:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -7.192207763608912e-05,
#           "percent_change_24h": 0.0005715728244952109,
#           "percent_change_7d": 0.0024526845431229118,
#           "percent_change_30d": 0.014099616380358894,
#           "price": 17.52113813716173,
#           "volume_24h": 14757740.302372247,
#           "market_cap": 344266483.0839471,
#           "total_supply": 4995.177581187298,
#           "circulating_supply": 4995.177581187298,
#           "timestamp": "2024-03-08T21:30:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.282907018377,
#           "percent_change_24h": 2.248293832409,
#           "percent_change_7d": 9.647686689825,
#           "percent_change_30d": 55.461140188549,
#           "price": 68919.76861453618,
#           "volume_24h": 58049884599.43,
#           "market_cap": 1354179515631.0144,
#           "total_supply": 19648637,
#           "circulating_supply": 19648637,
#           "timestamp": "2024-03-08T21:30:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-08T21:45:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -8.824200758923382e-06,
#           "percent_change_24h": 3.016008017745389e-05,
#           "percent_change_7d": 0.0001423523062462346,
#           "percent_change_30d": 0.0008083374005142204,
#           "price": 1,
#           "volume_24h": 845890.5530277321,
#           "market_cap": 19648637,
#           "total_supply": 285.45832838679905,
#           "circulating_supply": 285.45832838679905,
#           "timestamp": "2024-03-08T21:45:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -0.00015464198074261284,
#           "percent_change_24h": 0.0005285480991897252,
#           "percent_change_7d": 0.0024946896838147835,
#           "percent_change_30d": 0.014165917133905406,
#           "price": 17.524757761912063,
#           "volume_24h": 14824027.034900835,
#           "market_cap": 344337603.7767426,
#           "total_supply": 5002.588056098999,
#           "circulating_supply": 5002.588056098999,
#           "timestamp": "2024-03-08T21:45:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.607386438879,
#           "percent_change_24h": 2.075975399445,
#           "percent_change_7d": 9.798378654257,
#           "percent_change_30d": 55.639393133089,
#           "price": 68831.89259546105,
#           "volume_24h": 58224247693.52,
#           "market_cap": 1352452871631.202,
#           "total_supply": 19648637,
#           "circulating_supply": 19648637,
#           "timestamp": "2024-03-08T21:45:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-08T22:00:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -1.8740718729156343e-05,
#           "percent_change_24h": 2.3126282419481463e-05,
#           "percent_change_7d": 0.00013586412244020015,
#           "percent_change_30d": 0.0008013603137716635,
#           "price": 1,
#           "volume_24h": 856491.3301233392,
#           "market_cap": 19648637,
#           "total_supply": 287.29054502342973,
#           "circulating_supply": 287.29054502342973,
#           "timestamp": "2024-03-08T22:00:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -0.00032728480604580286,
#           "percent_change_24h": 0.0004038735635280079,
#           "percent_change_7d": 0.0023727085179633275,
#           "percent_change_30d": 0.013994823712792016,
#           "price": 17.463834273155243,
#           "volume_24h": 14957622.645668292,
#           "market_cap": 343140540.2613862,
#           "total_supply": 5017.194466533621,
#           "circulating_supply": 5017.194466533621,
#           "timestamp": "2024-03-08T22:00:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -1.281732329194,
#           "percent_change_24h": 1.581673801283,
#           "percent_change_7d": 9.292142986931,
#           "percent_change_30d": 54.807365519883,
#           "price": 68392.91212454476,
#           "volume_24h": 58577936276.56,
#           "market_cap": 1343827503708.0789,
#           "total_supply": 19648637,
#           "circulating_supply": 19648637,
#           "timestamp": "2024-03-08T22:00:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-08T22:15:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -1.5337806427672648e-05,
#           "percent_change_24h": 2.1173151567439452e-05,
#           "percent_change_7d": 0.00013862036212131524,
#           "percent_change_30d": 0.0008030438034493691,
#           "price": 1,
#           "volume_24h": 859808.4178670408,
#           "market_cap": 19648718,
#           "total_supply": 286.8839945593216,
#           "circulating_supply": 286.8839945593216,
#           "timestamp": "2024-03-08T22:15:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -0.00026835955559525727,
#           "percent_change_24h": 0.0003704582902374823,
#           "percent_change_7d": 0.0024253858562338446,
#           "percent_change_30d": 0.014050541010113554,
#           "price": 17.496605975615903,
#           "volume_24h": 15043729.101937322,
#           "market_cap": 343785876.7719917,
#           "total_supply": 5019.496213515186,
#           "circulating_supply": 5019.496213515186,
#           "timestamp": "2024-03-08T22:15:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -1.050488137893,
#           "percent_change_24h": 1.450151602075,
#           "percent_change_7d": 9.494124649803,
#           "percent_change_30d": 55.00056306683,
#           "price": 68490.11577025102,
#           "volume_24h": 58888378079.95,
#           "market_cap": 1345742970557.0151,
#           "total_supply": 19648718,
#           "circulating_supply": 19648718,
#           "timestamp": "2024-03-08T22:15:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-08T22:30:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -1.0871283774703912e-05,
#           "percent_change_24h": 2.013361989613707e-05,
#           "percent_change_7d": 0.00013968490844051484,
#           "percent_change_30d": 0.0007969311388911361,
#           "price": 1,
#           "volume_24h": 863916.0685732452,
#           "market_cap": 19648718,
#           "total_supply": 287.23159846299046,
#           "circulating_supply": 287.23159846299046,
#           "timestamp": "2024-03-08T22:30:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -0.00019003537340660172,
#           "percent_change_24h": 0.00035194555254751414,
#           "percent_change_7d": 0.0024417607234692193,
#           "percent_change_30d": 0.013930747250928988,
#           "price": 17.480490560718298,
#           "volume_24h": 15101676.681947473,
#           "market_cap": 343469229.52921575,
#           "total_supply": 5020.949245672333,
#           "circulating_supply": 5020.949245672333,
#           "timestamp": "2024-03-08T22:30:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.74367440884,
#           "percent_change_24h": 1.377285165613,
#           "percent_change_7d": 9.555457649821,
#           "percent_change_30d": 54.515851658669,
#           "price": 68407.22993271828,
#           "volume_24h": 59098105145.46,
#           "market_cap": 1344114370109.1406,
#           "total_supply": 19648718,
#           "circulating_supply": 19648718,
#           "timestamp": "2024-03-08T22:30:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-08T22:45:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -6.525555760512198e-06,
#           "percent_change_24h": 3.0134864425847654e-05,
#           "percent_change_7d": 0.00014140741714585155,
#           "percent_change_30d": 0.0008036666889334969,
#           "price": 1,
#           "volume_24h": 863934.8484157358,
#           "market_cap": 19648718,
#           "total_supply": 286.7416932161932,
#           "circulating_supply": 286.7416932161932,
#           "timestamp": "2024-03-08T22:45:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -0.0001143008055191994,
#           "percent_change_24h": 0.0005278384561403081,
#           "percent_change_7d": 0.002476874350529131,
#           "percent_change_30d": 0.014076923603950076,
#           "price": 17.515872933132027,
#           "volume_24h": 15132573.027354708,
#           "market_cap": 344164447.78694403,
#           "total_supply": 5022.531063005966,
#           "circulating_supply": 5022.531063005966,
#           "timestamp": "2024-03-08T22:45:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.447157870533,
#           "percent_change_24h": 2.064964625236,
#           "percent_change_7d": 9.689816752642,
#           "percent_change_30d": 55.070540875066,
#           "price": 68524.10537028375,
#           "volume_24h": 59200362585.9,
#           "market_cap": 1346410822622.991,
#           "total_supply": 19648718,
#           "circulating_supply": 19648718,
#           "timestamp": "2024-03-08T22:45:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-08T23:00:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -1.3697290475256333e-06,
#           "percent_change_24h": 2.4479978143630634e-05,
#           "percent_change_7d": 0.00013510468347508158,
#           "percent_change_30d": 0.0008012139606685606,
#           "price": 1,
#           "volume_24h": 866413.7175624929,
#           "market_cap": 19648718,
#           "total_supply": 287.5608635545943,
#           "circulating_supply": 287.5608635545943,
#           "timestamp": "2024-03-08T23:00:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -2.406819962937776e-05,
#           "percent_change_24h": 0.00043015003729975315,
#           "percent_change_7d": 0.002373992505025929,
#           "percent_change_30d": 0.014078534426973563,
#           "price": 17.571504140075078,
#           "volume_24h": 15224192.225167185,
#           "market_cap": 345257529.6841677,
#           "total_supply": 5052.876904473118,
#           "circulating_supply": 5052.876904473118,
#           "timestamp": "2024-03-08T23:00:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.093592081546,
#           "percent_change_24h": 1.672690022017,
#           "percent_change_7d": 9.231554646438,
#           "percent_change_30d": 54.746070018846,
#           "price": 68328.90177445734,
#           "volume_24h": 59201097803.37,
#           "market_cap": 1342575322216.0117,
#           "total_supply": 19648718,
#           "circulating_supply": 19648718,
#           "timestamp": "2024-03-08T23:00:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-08T23:15:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -2.4663366765288506e-06,
#           "percent_change_24h": 2.432840849034752e-05,
#           "percent_change_7d": 0.00013240973531296023,
#           "percent_change_30d": 0.0008014964241494677,
#           "price": 1,
#           "volume_24h": 864846.5727805353,
#           "market_cap": 19648718,
#           "total_supply": 287.368598097823,
#           "circulating_supply": 287.368598097823,
#           "timestamp": "2024-03-08T23:15:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -4.318696377935273e-05,
#           "percent_change_24h": 0.00042600432709805877,
#           "percent_change_7d": 0.00231857008713125,
#           "percent_change_30d": 0.014034660137212163,
#           "price": 17.51057111964719,
#           "volume_24h": 15143957.420256693,
#           "market_cap": 344060273.94889194,
#           "total_supply": 5031.98827454524,
#           "circulating_supply": 5031.98827454524,
#           "timestamp": "2024-03-08T23:15:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.168634827086,
#           "percent_change_24h": 1.663445626905,
#           "percent_change_7d": 9.053465016151,
#           "percent_change_30d": 54.802011494521,
#           "price": 68374.61758195094,
#           "volume_24h": 59133553680.93,
#           "market_cap": 1343473579225.596,
#           "total_supply": 19648718,
#           "circulating_supply": 19648718,
#           "timestamp": "2024-03-08T23:15:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-08T23:30:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -1.4492482085708701e-06,
#           "percent_change_24h": 2.5652453012509962e-05,
#           "percent_change_7d": 0.00013417815378524839,
#           "percent_change_30d": 0.0007995374966133401,
#           "price": 1,
#           "volume_24h": 864507.4027349123,
#           "market_cap": 19648718,
#           "total_supply": 287.5163571566126,
#           "circulating_supply": 287.5163571566126,
#           "timestamp": "2024-03-08T23:30:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -2.5403528363984015e-05,
#           "percent_change_24h": 0.0004496557690084575,
#           "percent_change_7d": 0.0023519770563469227,
#           "percent_change_30d": 0.014014903281001724,
#           "price": 17.5287629915616,
#           "volume_24h": 15153745.366990771,
#           "market_cap": 344417720.91003025,
#           "total_supply": 5039.806080795439,
#           "circulating_supply": 5039.806080795439,
#           "timestamp": "2024-03-08T23:30:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.099040867253,
#           "percent_change_24h": 1.753075269302,
#           "percent_change_7d": 9.16966509857,
#           "percent_change_30d": 54.639975814747,
#           "price": 68339.47881892916,
#           "volume_24h": 59079985338.01,
#           "market_cap": 1342783147580.112,
#           "total_supply": 19648718,
#           "circulating_supply": 19648718,
#           "timestamp": "2024-03-08T23:30:00.000Z"
#         }
#       }
#     },
#     {
#       "timestamp": "2024-03-08T23:45:00.000Z",
#       "quote": {
#         "BTC": {
#           "percent_change_1h": -6.34758249018759e-06,
#           "percent_change_24h": 2.4371270075688885e-05,
#           "percent_change_7d": 0.00013607890912042836,
#           "percent_change_30d": 0.0007953754086284029,
#           "price": 1,
#           "volume_24h": 867586.7589006517,
#           "market_cap": 19648718,
#           "total_supply": 287.9889117995073,
#           "circulating_supply": 287.9889117995073,
#           "timestamp": "2024-03-08T23:45:00.000Z"
#         },
#         "ETH": {
#           "percent_change_1h": -0.00011133915597767472,
#           "percent_change_24h": 0.0004274819026811843,
#           "percent_change_7d": 0.0023868789277259857,
#           "percent_change_30d": 0.013951205331947944,
#           "price": 17.540403161327692,
#           "volume_24h": 15217821.528547037,
#           "market_cap": 344646435.32323635,
#           "total_supply": 5051.441618955401,
#           "circulating_supply": 5051.441618955401,
#           "timestamp": "2024-03-08T23:45:00.000Z"
#         },
#         "USD": {
#           "percent_change_1h": -0.433078681926,
#           "percent_change_24h": 1.662786980328,
#           "percent_change_7d": 9.284302282153,
#           "percent_change_30d": 54.266350084875,
#           "price": 68227.34207794459,
#           "volume_24h": 59193138581.81,
#           "market_cap": 1340579804379.0671,
#           "total_supply": 19648718,
#           "circulating_supply": 19648718,
#           "timestamp": "2024-03-08T23:45:00.000Z"
#         }
#       }
#     }
#   ],
#   "id": 1,
#   "name": "Bitcoin",
#   "symbol": "BTC",
#   "is_active": 1,
#   "is_fiat": 0
# }
# Retrieved 95 quotes for cryptocurrency ID 1 on 2024-03-08 00:00:00
# Data saved to CSV file: historical_data/1/2024-03-08.csv
# Waiting for 5 second before the next request...
# Data backfill completed.
