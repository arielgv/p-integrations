# %% [markdown]
# # Active Market @ aevo

# %%
import requests

url = "https://api.aevo.xyz/markets"
headers = {"accept": "application/json"}
response = requests.get(url, headers=headers)

data = response.json()

filtered_data = [
    {
        "instrument_id": item["instrument_id"],
        "instrument_name": item["instrument_name"],
        "instrument_type": item["instrument_type"], 
        "underlying_asset": item["underlying_asset"]
    }
    for item in data
]

print(filtered_data)
# Out:
# [{'instrument_id': '17513', 'instrument_name': 'ALT-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'ALT'}, {'instrument_id': '8802', 'instrument_name': 'HPOS-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'HPOS'}, {'instrument_id': '8543', 'instrument_name': 'OX-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'OX'}, {'instrument_id': '9605', 'instrument_name': 'STRAX-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'STRAX'}, {'instrument_id': '19174', 'instrument_name': 'STRK-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'STRK'}, {'instrument_id': '9924', 'instrument_name': 'TRB-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'TRB'}, {'instrument_id': '20735', 'instrument_name': 'AR-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'AR'}, {'instrument_id': '13987', 'instrument_name': 'ATOM-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'ATOM'}, {'instrument_id': '12478', 'instrument_name': 'BEAM-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'BEAM'}, {'instrument_id': '8139', 'instrument_name': 'HIFI-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'HIFI'}, {'instrument_id': '13194', 'instrument_name': 'ORDI-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'ORDI'}, {'instrument_id': '13091', 'instrument_name': 'RNDR-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'RNDR'}, {'instrument_id': '5196', 'instrument_name': 'XRP-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'XRP'}, {'instrument_id': '9358', 'instrument_name': 'DYDX-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'DYDX'}, {'instrument_id': '6815', 'instrument_name': 'FRIEND-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'FRIEND'}, {'instrument_id': '10504', 'instrument_name': 'MEME-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'MEME'}, {'instrument_id': '11768', 'instrument_name': 'PYTH-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'PYTH'}, {'instrument_id': '5197', 'instrument_name': 'SOL-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'SOL'}, {'instrument_id': '20813', 'instrument_name': 'TON-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'TON'}, {'instrument_id': '17792', 'instrument_name': 'UMA-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'UMA'}, {'instrument_id': '9451', 'instrument_name': 'T-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'T'}, {'instrument_id': '12123', 'instrument_name': 'TRX-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'TRX'}, {'instrument_id': '7623', 'instrument_name': 'BANANA-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'BANANA'}, {'instrument_id': '4042', 'instrument_name': 'BNB-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'BNB'}, {'instrument_id': '3396', 'instrument_name': 'BTC-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'BTC'}, {'instrument_id': '10280', 'instrument_name': 'MINA-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'MINA'}, {'instrument_id': '9764', 'instrument_name': 'PRIME-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'PRIME'}, {'instrument_id': '11642', 'instrument_name': 'APT-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'APT'}, {'instrument_id': '7349', 'instrument_name': 'ARB-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'ARB'}, {'instrument_id': '19417', 'instrument_name': 'SHFL-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'SHFL'}, {'instrument_id': '17791', 'instrument_name': 'SUI-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'SUI'}, {'instrument_id': '16207', 'instrument_name': 'MANTA-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'MANTA'}, {'instrument_id': '5125', 'instrument_name': 'MATIC-PERP', 'instrument_type': 'PERPETUAL', 'underlying_asset': 'MATIC'}, {'instrument_id': '13882', 'instrument_name': '10000SATS-PERP', 'instrument_t ...
