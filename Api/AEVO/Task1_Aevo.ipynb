# %% [markdown]
# # task 1 : funding rate + market info monitor

# %% [markdown]
# # FUNDING RATE and next funding

# %% [markdown]
# no LongPositionSize and  shortPositionSize available

# %%
import requests
import time

#available assets:
# ["10000SATS","1000BONK","1000PEPE","ALT","APT","ARB","ATOM","AVAX","BANANA","BEAM","BEAMX","BITCOIN","BLAST","BLUR","BLZ","BNB","BTC","CANTO","CRV","DOGE","DYDX","DYM","ETH","FRIEND","GLMR","HIFI","HPOS","ILV","INJ","JITO","JUP","LDO","LINK","MANTA","MATIC","MEME","MINA","MKR","NMR","NTRN","OP","ORDI","OX","PARCL","PIXEL","PORTAL","PRIME","PYTH","RNDR","SEI","SHFL","SOL","STRAX","STRK","SUI","SYN","T","TAO","TIA","TRB","TRX","UMA","WLD","XRP","ZETA"]

tickers = ['ETH', 'BTC']  

while True:
    for ticker in tickers:

        asset_name = ticker + "-PERP"


        url = f"https://api.aevo.xyz/funding?instrument_name={asset_name}"


        headers = {"accept": "application/json"}

        response = requests.get(url, headers=headers)


        print(f"RESPONSE {ticker}: {response.text}")

        url = f"https://api.aevo.xyz/statistics?asset={ticker}&instrument_type=PERPETUAL"
        headers = {"accept": "application/json"}

        response = requests.get(url, headers=headers)

        print(response.text)

    time.sleep(10)
# Out:
# RESPONSE ETH: {"next_epoch":"1709154000000000000","funding_rate":"0.000155"}
# {"asset":"ETH","open_interest":{"total":"20506.963278"},"index_price":"3299.441473","index_daily_change":"44.124128","mark_price":"3306.19061","mark_price_24h_ago":"3252.518564","mark_daily_change":"53.672046","funding_daily_avg":"0.000086","daily_buy_volume":"1740170323.5323923","daily_sell_volume":"1756419164.4239686","daily_volume":"3496589487.956361","daily_volume_contracts":"1056041.35","total_volume":"17795.39194288"}
# RESPONSE BTC: {"next_epoch":"1709154000000000000","funding_rate":"0.00009"}
# ...
