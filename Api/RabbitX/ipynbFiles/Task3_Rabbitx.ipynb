# %%
from rabbitx import const
from rabbitx.client import Client, CandlePeriod, OrderSide, OrderType
from rabbitx.client import Client, WSClient, WSClientCallback
from websocket import WebSocketApp

# %%
TESTNETURL = 'https://api.testnet.rabbitx.io'


privkey = '0x1f173c6505de4108c564e21de1df1c8d3e8893b09c42f88af739148fc57ec946'


client = Client(api_url=TESTNETURL, api_key='7kk9OJMjJIZvr9L/z9D5S/m6f3RYX0f1/PskltMvU8Q=',public_jwt="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiI0MDAwMDAwMDAwIiwiZXhwIjo2NTQ4NDg3NTY5fQ.o_qBZltZdDHBH3zHPQkcRhVBQCtejIuyq8V1yj5kYq8", private_key=privkey)
client.onboarding.onboarding()
client.onboarding.init()
print(client.onboarding.onboarding())
print(client.trades.list(market_id="BTC-USD", p_limit=10))
print(client.markets.list())
# Out:
# {'profile': {'id': 22439, 'profile_type': 'trader', 'status': 'active', 'wallet': '0x2ddfa60e9c3a6b346cd4d750c0a507a8e825eeec', 'last_update': 1708552674118434, 'balance': '0', 'account_equity': '0', 'total_position_margin': '0', 'total_order_margin': '0', 'total_notional': '0', 'account_margin': '1', 'withdrawable_balance': '0', 'cum_unrealized_pnl': '0', 'health': '1', 'account_leverage': '1', 'cum_trading_volume': '0', 'leverage': {'AAVE-USD': '1', 'APT-USD': '1', 'ARB-USD': '1', 'BCH-USD': '1', 'BLUR-USD': '1', 'BNB-USD': '1', 'BTC-USD': '1', 'DOGE-USD': '1', 'ETH-USD': '1', 'INJ-USD': '1', 'JTO-USD': '1', 'LDO-USD': '1', 'LINK-USD': '1', 'MATIC-USD': '1', 'MEME-USD': '1', 'MKR-USD': '1', 'ORDI-USD': '1', 'PEPE1000-USD': '1', 'RLB-USD': '1', 'RNDR-USD': '1', 'SATS1000000-USD': '1', 'SEI-USD': '1', 'SOL-USD': '1', 'STG-USD': '1', 'STX-USD': '1', 'SUI-USD': '1', 'TIA-USD': '1', 'TON-USD': '1', 'TRB-USD': '1', 'WLD-USD': '1', 'XRP-USD': '1'}, 'last_liq_check': 0}, 'apiSecret': {'Key': 'Q0u2AT6jWXOCEcnyo6HNEu6CcER58h1R86HRBlX+eXo=', 'ProfileID': 22439, 'Secret': '0xe3fe398b06e6e2b1c39fbeb4c687c67a38e68b12cba6842ade56b8b565a67c60', 'Tag': '', 'Expiration': 1724006773, 'Status': 'API_GEN'}, 'jwt': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIyMjQzOSIsImV4cCI6MTcwODcyNTQ3NX0.NhpzhAMl1rZdYNNBvYsgJxK0ihaAAUqmw0lBDr95vFw'}
# [{'id': 'BTC-USD-17352912', 'market_id': 'BTC-USD', 'timestamp': 1708526583991922, 'price': '51112', 'size': '0.0024', 'liquidation': False, 'taker_side': 'short'}, {'id': 'BTC-USD-17352909', 'market_id': 'BTC-USD', 'timestamp': 1708526583991922, 'price': '51113', 'size': '0.0024', 'liquidation': False, 'taker_side': 'short'}, {'id': 'BTC-USD-17352906', 'market_id': 'BTC-USD', 'timestamp': 1708526583991922, 'price': '51121', 'size': '0.0024', 'liquidation': False, 'taker_side': 'short'}, {'id': 'BTC-USD-17352903', 'market_id': 'BTC-USD', 'timestamp': 1708526582579616, 'price': '51122', 'size': '0.0052', 'liquidation': True, 'taker_side': 'long'}, {'id': 'BTC-USD-17352900', 'market_id': 'BTC-USD', 'timestamp': 1708509655167447, 'price': '49445', 'size': '0.002', 'liquidation': False, 'taker_side': 'long'}, {'id': 'BTC-USD-17352897', 'market_id': 'BTC-USD', 'timestamp': 1708509655167447, 'price': '49445', 'size': '0.0016', 'liquidation': False, 'taker_side': 'long'}, {'id': 'BTC-USD-17352894', 'market_id': 'BTC-USD', 'timestamp': 1708502832636392, 'price': '49445', 'size': '0.0001', 'liquidation': False, 'taker_side': 'long'}, {'id': 'BTC-USD-17352891', 'market_id': 'BTC-USD', 'timestamp': 1708502522490207, 'price': '53859', 'size': '0.0002', 'liquidation': False, 'taker_side': 'short'}, {'id': 'BTC-USD-17352888', 'market_id': 'BTC-USD', 'timestamp': 1708419724119491, 'price': '48697', 'size': '0.0002', 'liquidation': False, 'taker_side': 'long'}, {'id': 'BTC-USD-17352885', 'market_id': 'BTC-USD', 'timestamp': 1708419606138079, 'price': '48697', 'size': '0.0002', 'liquidation': False, 'taker_side': 'long'}]
# [{'id': 'BTC-USD', 'status': 'active', 'min_initial_margin': '0.05', 'forced_margin': '0.03', 'liquidation_margin': '0.02', 'min_tick': '1', 'min_order': '0.0001', 'best_bid': '53284', 'best_ask': '0', 'market_price': '53284', 'index_price': '51377', 'last_trade_price': '51112', 'fair_price': '51890', 'instant_funding_rate': '0.0025', 'last_funding_rate_basis': '0.0025', 'last_update_time': 1708529164581028, 'last_update_sequence': 643179993, 'average_daily_volume_q': '30.4063', 'last_funding_update_time': 1708549200182227, 'icon_url': 'https://d3jcs7jdw2xltq.cloudfront.net/currencies/btc.svg', 'market_title': 'Bitcoin', 'base_currency': 'BTC', 'quote_currency': 'USD', 'product_type': 'perpetual', 'open_interest': '123.34', 'long_ratio': '0.54', 'short_ratio': '0.46', 'next_funding_rate_timestamp': 1708552800, 'average_daily_volume': '827.5831', 'last_trade_price_24high': '53859', 'last_trade_price_24low': '49445', 'last_trade_price_24h_change_premium': '-2738', 'last_trade_price_24h_change_basis': '-0.0508364433056685048', 'average_daily_volume_change_premium': '655.5203', 'average_daily_volume_change_basis': '3.8097735245503386'}, {'id': 'ETH-USD', 'status': 'active', 'min_initial_margin': '0.05', 'forced_margin': '0.03', 'liquidation_margin': '0.02', 'min_tick': '0.1', 'min_order': '0.001', 'best_bid': '2249.7', 'best_ask': '2251.3', 'market_price': '2250.5', 'index_price': '2925.4', 'last_trade_price': '2251.3', 'fair_price': '2896', 'instant_funding_rate': '-0.0024875', 'last_funding_rate_basis': '-0.0024875', 'last_update_time': 1708533044401434, 'last_update_sequence': 644576150, 'average_daily_volume_q': '18.768', 'last_funding_update_time': 1708549201940548, 'icon_url': 'https://d3jcs7jdw2xltq.cloudfront.net/currencies/eth.svg', 'market_title': 'Ethereum', 'base_currency': 'ETH', 'quote_currency': 'USD', 'product_type': 'perpetual', 'open_interest': '640.33', 'long_ratio': '0.49', 'short_ratio': '0.51', 'next_funding_rate_timestamp': 1708552800, 'average_daily_volume': '5574.2188', 'last_trade_price_24high': '2251.3', 'last_trade_price_24low': '2251.3', 'last_trade_price_24h_change_premium': '0', 'last_trade_price_24h_change_basis': '0', 'average_daily_volume_change_premium': '-6080.7613', 'average_daily_volume_change_basis': '-0.52173073208421865946'}, {'id': 'SOL-USD', 'status': 'active', 'min_initial_margin': '0.05', 'forced_margin': '0.03', 'liquidation_margin': '0.02', 'min_tick': '0.0001', 'min_order': '0.01', 'best_bid': '91.169', 'best_ask': '91.2977', 'market_price': '91.23335', 'index_price': '104.63', 'last_trade_price': '91.2977', 'fair_price': '103.5738', 'instant_funding_rate': '-0.0024875', 'last_funding_rate_basis': '-0.0024875', 'last_update_time': 1708471018405698, 'last_update_sequence': 1351252367, 'average_daily_volume_q': '212.99', 'last_funding_update_time': 1708549203668873, 'icon_url': 'https://d3jcs7jdw2xltq.cloudfront.net/currencies/sol.svg', 'market_title': 'Solana', 'base_currency': 'SOL', 'quote_currency': 'USD', 'product_type': 'perpetual', 'open_interest': '42.02', 'long_ratio': '0.52', 'short_ratio': '0.48', 'next_funding_rate_timestamp': 1708552800, 'average_daily_volume': '376.146524', 'last_trade_price_24high': '91.2977', 'last_trade_price_24low': '91.2977', 'last_trade_price_24h_change_premium': '0', 'last_trade_price_24h_change_basis': '0', 'average_daily_volume_change_premium': '-4224.932077', 'average_daily_volume_change_basis': '-0.91824818556278343396'}, {'id': 'ARB-USD', 'status': 'active', 'min_initial_margin': '0.05', 'forced_margin': '0.03', 'liquidation_margin': '0.02', 'min_tick': '0.0001', 'min_order': '1', 'best_bid': '1.8414', 'best_ask': '0', 'market_price': '1.8414', 'index_price': '1.8516', 'last_trade_price': '1.998', 'fair_price': '1.8477', 'instant_funding_rate': '0.0001645592376345370367876397686528911', 'last_funding_rate_basis': '0.00060373084288255539120333068784207885', 'last_update_time': 1708552671513256, 'last_update_sequence': 962600001, 'average_daily_ ...

# %%
client.positions.list()
# Out:
# []

# %%
EXPECTED_RESPONSE = """
GET /positions
Example response

{
    "success": true,
    "error": "",
    "result": [
            {'entry_price': '25532.188679245283018867924528301886794',
              'fair_price': '24351',
              'id': 'pos-BTC-USD-tr-7615',
              'liquidation_price': '26027.959333211210844477010441472797217',
              'margin': '64.53015',
              'market_id': 'BTC-USD',
              'notional': '1290.603',
              'profile_id': 7615,
              'side': 'short',
              'size': '0.053',
              'unrealized_pnl': '62.603000000000000000000000000000000082'}
    ]
}
"""
